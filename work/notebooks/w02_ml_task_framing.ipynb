# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mzayan-bit/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# The ML task is **scoring/ranking** rather than simple classification. Instead of predicting whether a page belongs to a fixed class, the goal is to assign every content page a score that represents how urgently it should be reviewed. Pages with higher scores are prioritized first for content refresh, expansion, monitoring, or other SEO actions.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The ideal target is a content opportunity score that represents how valuable it would be to review a page.
#
# Since there is no direct label saying "this page needs a refresh," a proxy target can be created using available search performance indicators such as traffic trend, impressions, sessions, clicks, and other engagement features.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# The success of the system is measured by how well it ranks pages that truly deserve review.
#
# A useful ranking places the highest-value opportunities near the top so the content team spends time on the pages that are most likely to benefit from improvement.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)

print("\nFirst 5 Rows:")
display(df.head())

print("\nExample Columns:")
print(df.columns.tolist()[:10])

# Example target column for future ML work
df["target_score"] = 0.0

print("\nExample Target:")
display(df[["trend_direction", "target_score"]].head())
# Out:
# Dataset Shape: (30000, 44)
#
# First 5 Rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## Unit of Analysis
#
# The unit of analysis is **one content page**.
#
# Each row in the dataset represents a single webpage and contains information about its search performance, engagement, and content characteristics. The future ML model will assign each page a score indicating how strongly it should be considered for content refresh or review.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A simple rule such as "refresh every page with declining traffic" is too limited because page performance depends on many different factors, including impressions, sessions, clicks, trend direction, and other engagement signals.
#
# Machine learning can analyze many features together and identify complex patterns that are difficult to capture with manually written rules. This allows the content team to prioritize pages more accurately and make better decisions about which pages should be refreshed first.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
